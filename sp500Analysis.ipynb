# %% [markdown]
# ---
# title: S&P 500 Trend Analysis
# author: Samantha Pang
# date: 2025-12-01
# date-modified: last-modified
# format:
#     html:
#         toc: true
#         code-fold: true
# ---

# %% [markdown]
# Note for yfiance:
# Main components
# Ticker: single ticker data
# Tickers: multiple tickers' data
# download: download market data for multiple tickers
# Market: get information about a market
# WebSocket and AsyncWebSocket: live streaming data
# Search: quotes and news from search
# Sector and Industry: sector and industry information
# EquityQuery and Screener: build query to screen market

# %% [markdown]
# Goal understand US trend
# what is yfiance?
# how stock market looks like using sp500, nasdaq, dow jones, Vanguard Total Stock Market ETF (VTI)
# international market trend using Vanguard Total International Stock ETF (VXUS)
# An ETF with a broad portfolio of international stocks and a 0.08% expense ratio.
# iShares Core MSCI Total International Stock ETF (IXUS): This ETF tracks the MSCI ACWI IMI ex USA index and has a 0.07% expense ratio.
# Fidelity ZERO International Index Fund (FZILX): This option also has a 0.00% expense ratio.
# what is candle chart
# how to use
# can it be interactive?

# %%
import yfinance as yf

# Pick a ticker, for example Apple
ticker = yf.Ticker("AAPL")

# Download recent price history (daily OHLCV)
data = ticker.history(period="1y")
data.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-11-11 00:00:00-05:00  224.204094  224.901615  220.716475  223.436813
# 2024-11-12 00:00:00-05:00  223.755689  224.792003  222.569896  223.436813
# 2024-11-13 00:00:00-05:00  223.217580  225.848241  221.972002  224.323654
# 2024-11-14 00:00:00-05:00  224.224027  228.060399  224.204094  227.412704
# 2024-11-15 00:00:00-05:00  225.599128  226.117293  223.476673  224.204086
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-11-11 00:00:00-05:00  42005600        0.0           0.0
# 2024-11-12 00:00:00-05:00  40398300        0.0           0.0
# 2024-11-13 00:00:00-05:00  48566200        0.0           0.0
# 2024-11-14 00:00:00-05:00  44923900        0.0           0.0
# 2024-11-15 00:00:00-05:00  47923700        0.0           0.0

# %%
ticker.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
data["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data = yf.download("AAPL", start="2023-01-01", end="2024-01-01", interval="1d")
data
# Out:
# C:\Users\neh2k\AppData\Local\Temp\ipykernel_7540\3113649342.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", start="2023-01-01", end="2024-01-01", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2023-01-03  123.330635  129.079551  122.443150  128.468178  112117500
# 2023-01-04  124.602715  126.870731  123.340517  125.125343   89113600
# 2023-01-05  123.281334  125.993089  123.024955  125.361991   80962700
# 2023-01-06  127.817375  128.478056  123.153159  124.257586   87754700
# 2023-01-09  128.339981  131.554653  128.083602  128.655538   70790800
# ...                ...         ...         ...         ...        ...
# 2023-12-22  191.974701  193.769503  191.349985  193.541423   37149600
# ...

# %%
# ticker.financials
# ticker.balance_sheet
# ticker.cashflow
# ticker.earnings
ticker.dividends
# Out:
# Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2024-08-12 00:00:00-04:00    0.250000
# 2024-11-08 00:00:00-05:00    0.250000
# 2025-02-10 00:00:00-05:00    0.250000
# 2025-05-12 00:00:00-04:00    0.260000
# 2025-08-11 00:00:00-04:00    0.260000
# Name: Dividends, Length: 88, dtype: float64

# %%
tickers = ["AAPL", "MSFT", "TSLA"]
data = yf.download(tickers, period="6mo")
data
# Out:
# C:\Users\neh2k\AppData\Local\Temp\ipykernel_7540\2526966150.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, period="6mo")
# [*********************100%***********************]  3 of 3 completed
# Price            Close                                High              \
# Ticker            AAPL        MSFT        TSLA        AAPL        MSFT
# Date
# 2025-05-12  210.551041  447.700745  318.380005  211.030507  447.810348
# 2025-05-13  212.688614  447.581207  334.070007  213.158082  449.105896
# 2025-05-14  212.089294  451.367981  347.679993  213.697470  452.324641
# 2025-05-15  211.210297  452.386322  342.820007  212.718595  455.441297
# 2025-05-16  211.020508  453.524445  349.980011  212.329036  453.614293
# ...                ...         ...         ...         ...         ...
# 2025-11-04  270.040009  514.330017  444.260010  271.489990  515.549988
# ...

# %%
# S&P 500 Index (just the index value)
spx = yf.download("^GSPC", period="1mo")

# Vanguard S&P 500 ETF (actually investable)
voo = yf.download("VOO", period="1mo")

# SPY ETF
spy = yf.download("SPY", period="1mo")

# # Indexes (cannot buy them directly)
# dow = yf.download("^DJI", period="1y")
# nasdaq_composite = yf.download("^IXIC", period="1y")
# nasdaq_100 = yf.download("^NDX", period="1y")

# # ETFs (you *can* buy these)
# dia = yf.download("DIA", period="1y")   # tracks Dow 30
# qqq = yf.download("QQQ", period="1y")   # tracks Nasdaq 100
# Out:
# C:\Users\neh2k\AppData\Local\Temp\ipykernel_7540\414331236.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   spx = yf.download("^GSPC", period="1mo")
# [*********************100%***********************]  1 of 1 completed
# C:\Users\neh2k\AppData\Local\Temp\ipykernel_7540\414331236.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   voo = yf.download("VOO", period="1mo")
# [*********************100%***********************]  1 of 1 completed
# C:\Users\neh2k\AppData\Local\Temp\ipykernel_7540\414331236.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   spy = yf.download("SPY", period="1mo")
# [*********************100%***********************]  1 of 1 completed

# %%
spx
# Out:
# Price             Close         High          Low         Open      Volume
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC       ^GSPC
# Date
# 2025-10-13  6654.720215  6668.680176  6620.709961  6622.529785  5303960000
# 2025-10-14  6644.310059  6680.700195  6555.069824  6602.490234  5666920000
# 2025-10-15  6671.060059  6724.120117  6612.109863  6688.270020  5633060000
# 2025-10-16  6629.069824  6709.339844  6593.990234  6689.020020  6048180000
# 2025-10-17  6664.009766  6678.879883  6603.759766  6613.270020  5358120000
# 2025-10-20  6735.129883  6744.350098  6690.049805  6690.049805  4672170000
# 2025-10-21  6735.350098  6752.160156  6722.029785  6736.750000  5245020000
# 2025-10-22  6699.399902  6741.750000  6655.689941  6741.339844  5710010000
# 2025-10-23  6738.439941  6749.529785  6700.140137  6703.649902  5565750000
# 2025-10-24  6791.689941  6807.109863  6772.069824  6772.069824  5058220000
# ...

# %%
voo
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker             VOO         VOO         VOO         VOO       VOO
# Date
# 2025-10-13  609.609985  611.030029  606.580017  607.369995   6968400
# 2025-10-14  608.750000  612.140015  600.510010  604.200012   7493500
# 2025-10-15  611.429993  616.210022  605.820007  613.070007   6504900
# 2025-10-16  607.390015  614.799988  604.140015  613.109985   7594800
# 2025-10-17  610.760010  612.020020  605.099976  606.340027   6911000
# 2025-10-20  617.169983  618.010010  613.510010  613.510010   4086200
# 2025-10-21  617.090027  618.739990  615.979980  617.330017   4216200
# 2025-10-22  613.969971  617.830017  609.830017  617.830017   6961600
# 2025-10-23  617.440002  618.469971  613.989990  614.250000   5851800
# 2025-10-24  622.549988  623.789978  621.210022  621.919983   5694900
# 2025-10-27  630.000000  630.289978  627.159973  627.739990   7804300
# ...

# %%
spy.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# import yfinance as yf
import pandas as pd
import mplfinance as mpf

data = yf.download("SPY", period="1mo")
data.info()
# Out:
# C:\Users\neh2k\AppData\Local\Temp\ipykernel_7540\4264258473.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("SPY", period="1mo")
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21 entries, 2025-10-13 to 2025-11-10
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   (Close, SPY)   21 non-null     float64
#  1   (High, SPY)    21 non-null     float64
#  2   (Low, SPY)     21 non-null     float64
#  3   (Open, SPY)    21 non-null     float64
#  4   (Volume, SPY)  21 non-null     int64
# dtypes: float64(4), int64(1)
# memory usage: 1008.0 bytes

# %%
# for col in data.columns:
#     # data[col] = pd.to_numeric(data[col], errors="coerce")
#     data[col] = data[col].astype(int)
data.columns = ['Close', 'High', 'Low', 'Open', 'Volume']
data.info()
mpf.plot(data, type="candle", style="yahoo", volume=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21 entries, 2025-10-13 to 2025-11-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   21 non-null     int64
#  1   High    21 non-null     int64
#  2   Low     21 non-null     int64
#  3   Open    21 non-null     int64
#  4   Volume  21 non-null     int64
# dtypes: int64(5)
# memory usage: 1008.0 bytes
